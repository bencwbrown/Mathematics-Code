# %%
P1 = Polyhedron(vertices = [ [0,0], [5,0], [0,5] ])
P2 = Polyhedron(vertices = [ [0,0], [-3,0], [0,-3] ])

# %%
P1
# Out:
# A 2-dimensional polyhedron in ZZ^2 defined as the convex hull of 3 vertices

# %%
P2
# Out:
# A 2-dimensional polyhedron in ZZ^2 defined as the convex hull of 3 vertices

# %%
P3 = P1.minkowski_sum(P2); P3
# Out:
# A 2-dimensional polyhedron in ZZ^2 defined as the convex hull of 6 vertices

# %%
for q in P3.Hrepresentation():
    print(q)
# Out:
# An inequality (0, -1) x + 5 >= 0
# An inequality (1, 1) x + 3 >= 0
# An inequality (1, 0) x + 3 >= 0
# An inequality (0, 1) x + 3 >= 0
# An inequality (-1, 0) x + 5 >= 0
# An inequality (-1, -1) x + 5 >= 0

# %%
for q in P3.Vrepresentation():
    print(q)
# Out:
# A vertex at (-3, 0)
# A vertex at (-3, 5)
# A vertex at (0, -3)
# A vertex at (5, 0)
# A vertex at (5, -3)
# A vertex at (0, 5)

# %%
P1.vertices()
# Out:
# (A vertex at (-5, -3),
#  A vertex at (-5, 2),
#  A vertex at (4, 4),
#  A vertex at (2, -4))

# %%
P1.pyramid().plot()
# Out:
# Graphics3d Object

# %%
P3 = Polyhedron(vertices=[(0,0,0), (0,0,1/2), (0,1/2,0), (1/2,0,0), (3/4,1/5,3/2)]); P3
# Out:
# A 3-dimensional polyhedron in QQ^3 defined as the convex hull of 5 vertices (use the .plot() method to plot)

# %%
P3.plot()
# Out:
# Graphics3d Object
