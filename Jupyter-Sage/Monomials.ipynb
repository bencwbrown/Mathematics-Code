# %% [markdown]
# * https://doc.sagemath.org/html/en/reference/polynomial_rings/sage/rings/monomials.html
# *

# %%
from sage.repl.display.pretty_print import SagePrettyPrinter

# %%
R.<a,b,c,x,y,z> = QQ[]

# %%
len(monomials([a,b,c], [5,5,5]))
# Out:
# 125

# %%
macaulay2('')
# Out:
# ---------------------------------------------------------------------------
# ExceptionPexpect                          Traceback (most recent call last)
# /Applications/SageMath-9.1.app/Contents/Resources/sage/local/lib/python3.7/site-packages/sage/interfaces/expect.py in _start(self, alt_message, block_during_init)
#     502                         preexec_fn=lambda: signal.signal(signal.SIGPIPE, signal.SIG_DFL),
# --> 503                         quit_string=self._quit_string())
#     504             except (ExceptionPexpect, pexpect.EOF) as e:
#
# /Applications/SageMath-9.1.app/Contents/Resources/sage/local/lib/python3.7/site-packages/sage/interfaces/sagespawn.pyx in sage.interfaces.sagespawn.SageSpawn.__init__ (build/cythonized/sage/interfaces/sagespawn.c:1962)()
#      64
# ---> 65         with ContainChildren(silent=True):
#      66             spawn.__init__(self, *args, **kwds)
#
# ...

# %%
R = ZZ/101[a,b,c,Degrees=>{{1,2},{2,1},{1,0}}]
